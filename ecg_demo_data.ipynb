# %%
from platform import python_version
import sys
print(sys.executable)
print(python_version())
# Out:
# c:\Users\Tudi\AppData\Local\Programs\Python\Python310\python.exe
# 3.10.5

# %% [markdown]
# # DATA ACQUISION

# %%
import pandas as pd

df_100 = pd.read_csv('100.csv')
df_101 = pd.read_csv('101.csv')
df_103 = pd.read_csv('103.csv')
df_105 = pd.read_csv('105.csv')
df_106 = pd.read_csv('106.csv')
df_107 = pd.read_csv('107.csv')
df_108 = pd.read_csv('108.csv')
df_109 = pd.read_csv('109.csv')
df_111 = pd.read_csv('111.csv')
df_112 = pd.read_csv('112.csv')
df_113 = pd.read_csv('113.csv')
df_114 = pd.read_csv('114.csv')
df_115 = pd.read_csv('115.csv')
df_116 = pd.read_csv('116.csv')
df_117 = pd.read_csv('117.csv')
df_118 = pd.read_csv('118.csv')
df_119 = pd.read_csv('119.csv')
df_121 = pd.read_csv('121.csv')
df_122 = pd.read_csv('122.csv')
df_123 = pd.read_csv('123.csv')
df_124 = pd.read_csv('124.csv')
df_200 = pd.read_csv('200.csv')
df_201 = pd.read_csv('201.csv')
df_202 = pd.read_csv('202.csv')
df_203 = pd.read_csv('203.csv')
df_205 = pd.read_csv('205.csv')
df_207 = pd.read_csv('207.csv')
df_208 = pd.read_csv('208.csv')
df_209 = pd.read_csv('209.csv')
df_210 = pd.read_csv('210.csv')
df_212 = pd.read_csv('212.csv')
df_213 = pd.read_csv('213.csv')
df_214 = pd.read_csv('214.csv')
df_215 = pd.read_csv('215.csv')
df_217 = pd.read_csv('217.csv')
df_219 = pd.read_csv('219.csv')
df_220 = pd.read_csv('220.csv')
df_221 = pd.read_csv('221.csv')
df_222 = pd.read_csv('222.csv')
df_223 = pd.read_csv('223.csv')
df_228 = pd.read_csv('228.csv')
df_230 = pd.read_csv('230.csv')
df_231 = pd.read_csv('231.csv')
df_232 = pd.read_csv('232.csv')
df_233 = pd.read_csv('233.csv')
df_234 = pd.read_csv('234.csv')

# %%
df_100anno = pd.read_csv('100annotations.csv')
df_101anno = pd.read_csv('101annotations.csv')
df_103anno = pd.read_csv('103annotations.csv')
df_105anno = pd.read_csv('105anno.csv')
df_106anno = pd.read_csv('106anno.csv')
df_107anno = pd.read_csv('107anno.csv')
df_108anno = pd.read_csv('108anno.csv')
df_109anno = pd.read_csv('109anno.csv')
df_111anno = pd.read_csv('111anno.csv')
df_112anno = pd.read_csv('112anno.csv')
df_113anno = pd.read_csv('113anno.csv')
df_114anno = pd.read_csv('114anno.csv')
df_115anno = pd.read_csv('115anno.csv')
df_116anno = pd.read_csv('116anno.csv')
df_117anno = pd.read_csv('117anno.csv')
df_118anno = pd.read_csv('118anno.csv')
df_119anno = pd.read_csv('119anno.csv')
df_121anno = pd.read_csv('121anno.csv')
df_122anno = pd.read_csv('122anno.csv')
df_123anno = pd.read_csv('123anno.csv')
df_124anno = pd.read_csv('124anno.csv')
df_200anno = pd.read_csv('200anno.csv')
df_201anno = pd.read_csv('201anno.csv')
df_202anno = pd.read_csv('202anno.csv')
df_203anno = pd.read_csv('203anno.csv')
df_205anno = pd.read_csv('205anno.csv')
df_207anno = pd.read_csv('207anno.csv')
df_208anno = pd.read_csv('208anno.csv')
df_209anno = pd.read_csv('209anno.csv')
df_210anno = pd.read_csv('210anno.csv')
df_212anno = pd.read_csv('212anno.csv')
df_215anno = pd.read_csv('215anno.csv')
df_217anno = pd.read_csv('217anno.csv')
df_213anno = pd.read_csv('213anno.csv')
df_214anno = pd.read_csv('214anno.csv')
df_219anno = pd.read_csv('219anno.csv')
df_220anno = pd.read_csv('220anno.csv')
df_221anno = pd.read_csv('221anno.csv')
df_222anno = pd.read_csv('222anno.csv')
df_223anno = pd.read_csv('223anno.csv')
df_228anno = pd.read_csv('228anno.csv')
df_230anno = pd.read_csv('230anno.csv')
df_231anno = pd.read_csv('231anno.csv')
df_232anno = pd.read_csv('232anno.csv')
df_233anno = pd.read_csv('233anno.csv')
df_234anno = pd.read_csv('234anno.csv')

# %% [markdown]
# # Data normalization

# %%
df_100.iloc[:,1] = (df_100.iloc[:,1]-df_100.iloc[:,1].min())/(df_100.iloc[:,1].max()-df_100.iloc[:,1].min())
df_101.iloc[:,1] = (df_101.iloc[:,1]-df_101.iloc[:,1].min())/(df_101.iloc[:,1].max()-df_101.iloc[:,1].min())
df_103.iloc[:,1] = (df_103.iloc[:,1]-df_103.iloc[:,1].min())/(df_103.iloc[:,1].max()-df_103.iloc[:,1].min())
df_105.iloc[:,1] = (df_105.iloc[:,1]-df_105.iloc[:,1].min())/(df_105.iloc[:,1].max()-df_105.iloc[:,1].min())
df_106.iloc[:,1] = (df_106.iloc[:,1]-df_106.iloc[:,1].min())/(df_106.iloc[:,1].max()-df_106.iloc[:,1].min())
df_107.iloc[:,1] = (df_107.iloc[:,1]-df_107.iloc[:,1].min())/(df_107.iloc[:,1].max()-df_107.iloc[:,1].min())
df_108.iloc[:,1] = (df_108.iloc[:,1]-df_108.iloc[:,1].min())/(df_108.iloc[:,1].max()-df_108.iloc[:,1].min())
df_109.iloc[:,1] = (df_109.iloc[:,1]-df_109.iloc[:,1].min())/(df_109.iloc[:,1].max()-df_109.iloc[:,1].min())
df_111.iloc[:,1] = (df_111.iloc[:,1]-df_111.iloc[:,1].min())/(df_111.iloc[:,1].max()-df_111.iloc[:,1].min())
df_112.iloc[:,1] = (df_112.iloc[:,1]-df_112.iloc[:,1].min())/(df_112.iloc[:,1].max()-df_112.iloc[:,1].min())
df_113.iloc[:,1] = (df_113.iloc[:,1]-df_113.iloc[:,1].min())/(df_113.iloc[:,1].max()-df_113.iloc[:,1].min())
df_114.iloc[:,1] = (df_114.iloc[:,1]-df_114.iloc[:,1].min())/(df_114.iloc[:,1].max()-df_114.iloc[:,1].min())
df_115.iloc[:,1] = (df_115.iloc[:,1]-df_115.iloc[:,1].min())/(df_115.iloc[:,1].max()-df_115.iloc[:,1].min())
df_116.iloc[:,1] = (df_116.iloc[:,1]-df_116.iloc[:,1].min())/(df_116.iloc[:,1].max()-df_116.iloc[:,1].min())
df_117.iloc[:,1] = (df_117.iloc[:,1]-df_117.iloc[:,1].min())/(df_117.iloc[:,1].max()-df_117.iloc[:,1].min())
df_118.iloc[:,1] = (df_118.iloc[:,1]-df_118.iloc[:,1].min())/(df_118.iloc[:,1].max()-df_118.iloc[:,1].min())
df_119.iloc[:,1] = (df_119.iloc[:,1]-df_119.iloc[:,1].min())/(df_119.iloc[:,1].max()-df_119.iloc[:,1].min())
df_121.iloc[:,1] = (df_121.iloc[:,1]-df_121.iloc[:,1].min())/(df_121.iloc[:,1].max()-df_121.iloc[:,1].min())
df_122.iloc[:,1] = (df_122.iloc[:,1]-df_122.iloc[:,1].min())/(df_122.iloc[:,1].max()-df_122.iloc[:,1].min())
df_123.iloc[:,1] = (df_123.iloc[:,1]-df_123.iloc[:,1].min())/(df_123.iloc[:,1].max()-df_123.iloc[:,1].min())
df_124.iloc[:,1] = (df_124.iloc[:,1]-df_124.iloc[:,1].min())/(df_124.iloc[:,1].max()-df_124.iloc[:,1].min())
df_200.iloc[:,1] = (df_200.iloc[:,1]-df_200.iloc[:,1].min())/(df_200.iloc[:,1].max()-df_200.iloc[:,1].min())
df_201.iloc[:,1] = (df_201.iloc[:,1]-df_201.iloc[:,1].min())/(df_201.iloc[:,1].max()-df_201.iloc[:,1].min())
df_202.iloc[:,1] = (df_202.iloc[:,1]-df_202.iloc[:,1].min())/(df_202.iloc[:,1].max()-df_202.iloc[:,1].min())
df_203.iloc[:,1] = (df_203.iloc[:,1]-df_203.iloc[:,1].min())/(df_203.iloc[:,1].max()-df_203.iloc[:,1].min())
df_205.iloc[:,1] = (df_205.iloc[:,1]-df_205.iloc[:,1].min())/(df_205.iloc[:,1].max()-df_205.iloc[:,1].min())
df_207.iloc[:,1] = (df_207.iloc[:,1]-df_207.iloc[:,1].min())/(df_207.iloc[:,1].max()-df_207.iloc[:,1].min())
df_208.iloc[:,1] = (df_208.iloc[:,1]-df_208.iloc[:,1].min())/(df_208.iloc[:,1].max()-df_208.iloc[:,1].min())
df_209.iloc[:,1] = (df_209.iloc[:,1]-df_209.iloc[:,1].min())/(df_209.iloc[:,1].max()-df_209.iloc[:,1].min())
df_210.iloc[:,1] = (df_210.iloc[:,1]-df_210.iloc[:,1].min())/(df_210.iloc[:,1].max()-df_210.iloc[:,1].min())
df_212.iloc[:,1] = (df_212.iloc[:,1]-df_212.iloc[:,1].min())/(df_212.iloc[:,1].max()-df_212.iloc[:,1].min())
df_213.iloc[:,1] = (df_213.iloc[:,1]-df_213.iloc[:,1].min())/(df_213.iloc[:,1].max()-df_213.iloc[:,1].min())
df_214.iloc[:,1] = (df_214.iloc[:,1]-df_214.iloc[:,1].min())/(df_214.iloc[:,1].max()-df_214.iloc[:,1].min())
df_215.iloc[:,1] = (df_215.iloc[:,1]-df_215.iloc[:,1].min())/(df_215.iloc[:,1].max()-df_215.iloc[:,1].min())
df_217.iloc[:,1] = (df_217.iloc[:,1]-df_217.iloc[:,1].min())/(df_217.iloc[:,1].max()-df_217.iloc[:,1].min())
df_219.iloc[:,1] = (df_219.iloc[:,1]-df_219.iloc[:,1].min())/(df_219.iloc[:,1].max()-df_219.iloc[:,1].min())
df_220.iloc[:,1] = (df_220.iloc[:,1]-df_220.iloc[:,1].min())/(df_220.iloc[:,1].max()-df_220.iloc[:,1].min())
df_221.iloc[:,1] = (df_221.iloc[:,1]-df_221.iloc[:,1].min())/(df_221.iloc[:,1].max()-df_221.iloc[:,1].min())
df_222.iloc[:,1] = (df_222.iloc[:,1]-df_222.iloc[:,1].min())/(df_222.iloc[:,1].max()-df_222.iloc[:,1].min())
df_223.iloc[:,1] = (df_223.iloc[:,1]-df_223.iloc[:,1].min())/(df_223.iloc[:,1].max()-df_223.iloc[:,1].min())
df_228.iloc[:,1] = (df_228.iloc[:,1]-df_228.iloc[:,1].min())/(df_228.iloc[:,1].max()-df_228.iloc[:,1].min())
df_230.iloc[:,1] = (df_230.iloc[:,1]-df_230.iloc[:,1].min())/(df_230.iloc[:,1].max()-df_230.iloc[:,1].min())
df_231.iloc[:,1] = (df_231.iloc[:,1]-df_231.iloc[:,1].min())/(df_231.iloc[:,1].max()-df_231.iloc[:,1].min())
df_232.iloc[:,1] = (df_232.iloc[:,1]-df_232.iloc[:,1].min())/(df_232.iloc[:,1].max()-df_232.iloc[:,1].min())
df_233.iloc[:,1] = (df_233.iloc[:,1]-df_233.iloc[:,1].min())/(df_233.iloc[:,1].max()-df_233.iloc[:,1].min())
df_234.iloc[:,1] = (df_234.iloc[:,1]-df_234.iloc[:,1].min())/(df_234.iloc[:,1].max()-df_234.iloc[:,1].min())

# %% [markdown]
# # Pre-processing
# Adding new features

# %%
df_100anno.insert(3,'Patient','NULL')
df_101anno.insert(3,'Patient','NULL')
df_103anno.insert(3,'Patient','NULL')
df_105anno.insert(3,'Patient','NULL')
df_106anno.insert(3,'Patient','NULL')
df_107anno.insert(3,'Patient','NULL')
df_108anno.insert(3,'Patient','NULL')
df_109anno.insert(3,'Patient','NULL')
df_111anno.insert(3,'Patient','NULL')
df_112anno.insert(3,'Patient','NULL')
df_113anno.insert(3,'Patient','NULL')
df_114anno.insert(3,'Patient','NULL')
df_115anno.insert(3,'Patient','NULL')
df_116anno.insert(3,'Patient','NULL')
df_117anno.insert(3,'Patient','NULL')
df_118anno.insert(3,'Patient','NULL')
df_119anno.insert(3,'Patient','NULL')
df_121anno.insert(3,'Patient','NULL')
df_122anno.insert(3,'Patient','NULL')
df_123anno.insert(3,'Patient','NULL')
df_124anno.insert(3,'Patient','NULL')
df_200anno.insert(3,'Patient','NULL')
df_201anno.insert(3,'Patient','NULL')
df_202anno.insert(3,'Patient','NULL')
df_203anno.insert(3,'Patient','NULL')
df_205anno.insert(3,'Patient','NULL')
df_207anno.insert(3,'Patient','NULL')
df_208anno.insert(3,'Patient','NULL')
df_209anno.insert(3,'Patient','NULL')
df_210anno.insert(3,'Patient','NULL')
df_212anno.insert(3,'Patient','NULL')
df_213anno.insert(3,'Patient','NULL')
df_214anno.insert(3,'Patient','NULL')
df_215anno.insert(3,'Patient','NULL')
df_217anno.insert(3,'Patient','NULL')
df_219anno.insert(3,'Patient','NULL')
df_220anno.insert(3,'Patient','NULL')
df_221anno.insert(3,'Patient','NULL')
df_222anno.insert(3,'Patient','NULL')
df_223anno.insert(3,'Patient','NULL')
df_228anno.insert(3,'Patient','NULL')
df_230anno.insert(3,'Patient','NULL')
df_231anno.insert(3,'Patient','NULL')
df_232anno.insert(3,'Patient','NULL')
df_233anno.insert(3,'Patient','NULL')
df_234anno.insert(3,'Patient','NULL')
df_100anno.insert(4,'MLII','NULL')
df_101anno.insert(4,'MLII','NULL')
df_103anno.insert(4,'MLII','NULL')
df_105anno.insert(4,'MLII','NULL')
df_106anno.insert(4,'MLII','NULL')
df_107anno.insert(4,'MLII','NULL')
df_108anno.insert(4,'MLII','NULL')
df_109anno.insert(4,'MLII','NULL')
df_111anno.insert(4,'MLII','NULL')
df_112anno.insert(4,'MLII','NULL')
df_113anno.insert(4,'MLII','NULL')
df_114anno.insert(4,'MLII','NULL')
df_115anno.insert(4,'MLII','NULL')
df_116anno.insert(4,'MLII','NULL')
df_117anno.insert(4,'MLII','NULL')
df_118anno.insert(4,'MLII','NULL')
df_119anno.insert(4,'MLII','NULL')
df_121anno.insert(4,'MLII','NULL')
df_122anno.insert(4,'MLII','NULL')
df_123anno.insert(4,'MLII','NULL')
df_124anno.insert(4,'MLII','NULL')
df_200anno.insert(4,'MLII','NULL')
df_201anno.insert(4,'MLII','NULL')
df_202anno.insert(4,'MLII','NULL')
df_203anno.insert(4,'MLII','NULL')
df_205anno.insert(4,'MLII','NULL')
df_207anno.insert(4,'MLII','NULL')
df_208anno.insert(4,'MLII','NULL')
df_209anno.insert(4,'MLII','NULL')
df_210anno.insert(4,'MLII','NULL')
df_212anno.insert(4,'MLII','NULL')
df_213anno.insert(4,'MLII','NULL')
df_214anno.insert(4,'MLII','NULL')
df_215anno.insert(4,'MLII','NULL')
df_217anno.insert(4,'MLII','NULL')
df_219anno.insert(4,'MLII','NULL')
df_220anno.insert(4,'MLII','NULL')
df_221anno.insert(4,'MLII','NULL')
df_222anno.insert(4,'MLII','NULL')
df_223anno.insert(4,'MLII','NULL')
df_228anno.insert(4,'MLII','NULL')
df_230anno.insert(4,'MLII','NULL')
df_231anno.insert(4,'MLII','NULL')
df_232anno.insert(4,'MLII','NULL')
df_233anno.insert(4,'MLII','NULL')
df_234anno.insert(4,'MLII','NULL')

# %%
for index in range(1,51):
    df_100anno.insert(4+index,index,'NULL')
    df_101anno.insert(4+index,index,'NULL')
    df_103anno.insert(4+index,index,'NULL')
    df_105anno.insert(4+index,index,'NULL')
    df_106anno.insert(4+index,index,'NULL')
    df_107anno.insert(4+index,index,'NULL')
    df_108anno.insert(4+index,index,'NULL')
    df_109anno.insert(4+index,index,'NULL')
    df_111anno.insert(4+index,index,'NULL')
    df_112anno.insert(4+index,index,'NULL')
    df_113anno.insert(4+index,index,'NULL')
    df_114anno.insert(4+index,index,'NULL')
    df_115anno.insert(4+index,index,'NULL')
    df_116anno.insert(4+index,index,'NULL')
    df_117anno.insert(4+index,index,'NULL')
    df_118anno.insert(4+index,index,'NULL')
    df_119anno.insert(4+index,index,'NULL')
    df_121anno.insert(4+index,index,'NULL')
    df_122anno.insert(4+index,index,'NULL')
    df_123anno.insert(4+index,index,'NULL')
    df_124anno.insert(4+index,index,'NULL')
    df_200anno.insert(4+index,index,'NULL')
    df_201anno.insert(4+index,index,'NULL')
    df_202anno.insert(4+index,index,'NULL')
    df_203anno.insert(4+index,index,'NULL')
    df_205anno.insert(4+index,index,'NULL')
    df_207anno.insert(4+index,index,'NULL')
    df_208anno.insert(4+index,index,'NULL')
    df_209anno.insert(4+index,index,'NULL')
    df_210anno.insert(4+index,index,'NULL')
    df_212anno.insert(4+index,index,'NULL')
    df_213anno.insert(4+index,index,'NULL')
    df_214anno.insert(4+index,index,'NULL')
    df_215anno.insert(4+index,index,'NULL')
    df_217anno.insert(4+index,index,'NULL')
    df_219anno.insert(4+index,index,'NULL')
    df_220anno.insert(4+index,index,'NULL')
    df_221anno.insert(4+index,index,'NULL')
    df_222anno.insert(4+index,index,'NULL')
    df_223anno.insert(4+index,index,'NULL')
    df_228anno.insert(4+index,index,'NULL')
    df_230anno.insert(4+index,index,'NULL')
    df_231anno.insert(4+index,index,'NULL')
    df_232anno.insert(4+index,index,'NULL')
    df_233anno.insert(4+index,index,'NULL')
    df_234anno.insert(4+index,index,'NULL')

# %% [markdown]
# # DATA CLEANING
#
# Using a simple imputer to fill in the gaps. Afterwards, for each anomaly at a specific index, we extend that anomaly with 200 instances before and after.

# %%
# we want to process only MLII data so this dataset is redundant
# Sample_104anno = df_104anno.iloc[:,1].to_numpy()

Sample_100anno = df_100anno.iloc[:,1].to_numpy()
Sample_101anno = df_101anno.iloc[:,1].to_numpy()
Sample_103anno = df_103anno.iloc[:,1].to_numpy()
Sample_105anno = df_105anno.iloc[:,1].to_numpy()
Sample_106anno = df_106anno.iloc[:,1].to_numpy()
Sample_107anno = df_107anno.iloc[:,1].to_numpy()
Sample_108anno = df_108anno.iloc[:,1].to_numpy()
Sample_109anno = df_109anno.iloc[:,1].to_numpy()
Sample_111anno = df_111anno.iloc[:,1].to_numpy()
Sample_112anno = df_112anno.iloc[:,1].to_numpy()
Sample_113anno = df_113anno.iloc[:,1].to_numpy()
Sample_114anno = df_114anno.iloc[:,1].to_numpy()
Sample_115anno = df_115anno.iloc[:,1].to_numpy()
Sample_116anno = df_116anno.iloc[:,1].to_numpy()
Sample_117anno = df_117anno.iloc[:,1].to_numpy()
Sample_118anno = df_118anno.iloc[:,1].to_numpy()
Sample_119anno = df_119anno.iloc[:,1].to_numpy()
Sample_121anno = df_121anno.iloc[:,1].to_numpy()
Sample_122anno = df_122anno.iloc[:,1].to_numpy()
Sample_123anno = df_123anno.iloc[:,1].to_numpy()
Sample_124anno = df_124anno.iloc[:,1].to_numpy()
Sample_200anno = df_200anno.iloc[:,1].to_numpy()
Sample_201anno = df_201anno.iloc[:,1].to_numpy()
Sample_202anno = df_202anno.iloc[:,1].to_numpy()
Sample_203anno = df_203anno.iloc[:,1].to_numpy()
Sample_205anno = df_205anno.iloc[:,1].to_numpy()
Sample_207anno = df_207anno.iloc[:,1].to_numpy()
Sample_208anno = df_208anno.iloc[:,1].to_numpy()
Sample_209anno = df_209anno.iloc[:,1].to_numpy()
Sample_210anno = df_210anno.iloc[:,1].to_numpy()
Sample_212anno = df_212anno.iloc[:,1].to_numpy()
Sample_213anno = df_213anno.iloc[:,1].to_numpy()
Sample_214anno = df_214anno.iloc[:,1].to_numpy()
Sample_215anno = df_215anno.iloc[:,1].to_numpy()
Sample_217anno = df_217anno.iloc[:,1].to_numpy()
Sample_220anno = df_220anno.iloc[:,1].to_numpy()
Sample_221anno = df_221anno.iloc[:,1].to_numpy()
Sample_222anno = df_222anno.iloc[:,1].to_numpy()
Sample_223anno = df_223anno.iloc[:,1].to_numpy()
Sample_228anno = df_228anno.iloc[:,1].to_numpy()
Sample_230anno = df_230anno.iloc[:,1].to_numpy()
Sample_231anno = df_231anno.iloc[:,1].to_numpy()
Sample_232anno = df_232anno.iloc[:,1].to_numpy()
Sample_233anno = df_233anno.iloc[:,1].to_numpy()
Sample_234anno = df_234anno.iloc[:,1].to_numpy()

for index,x in enumerate(Sample_209anno):
    df_209anno.at[index,'MLII'] = df_209.at[x,'\'MLII\'']
    df_209anno.at[index,'Patient'] = '209'
for index,x in enumerate(Sample_210anno):
    df_210anno.at[index,'MLII'] = df_210.at[x,'\'MLII\'']
    df_210anno.at[index,'Patient'] = '210'
for index,x in enumerate(Sample_212anno):
    df_212anno.at[index,'MLII'] = df_212.at[x,'\'MLII\'']
    df_212anno.at[index,'Patient'] = '212'
for index,x in enumerate(Sample_213anno):
    df_213anno.at[index,'MLII'] = df_213.at[x,'\'MLII\'']
    df_213anno.at[index,'Patient'] = '213'
for index,x in enumerate(Sample_214anno):
    df_214anno.at[index,'MLII'] = df_214.at[x,'\'MLII\'']
    df_214anno.at[index,'Patient'] = '214'
for index,x in enumerate(Sample_215anno):
    df_215anno.at[index,'MLII'] = df_215.at[x,'\'MLII\'']
    df_215anno.at[index,'Patient'] = '215'
for index,x in enumerate(Sample_217anno):
    df_217anno.at[index,'MLII'] = df_217.at[x,'\'MLII\'']
    df_217anno.at[index,'Patient'] = '217'
for index,x in enumerate(Sample_220anno):
    df_220anno.at[index,'MLII'] = df_220.at[x,'\'MLII\'']
    df_220anno.at[index,'Patient'] = '220'
for index,x in enumerate(Sample_221anno):
    df_221anno.at[index,'MLII'] = df_221.at[x,'\'MLII\'']
    df_221anno.at[index,'Patient'] = '221'
for index,x in enumerate(Sample_222anno):
    df_222anno.at[index,'MLII'] = df_222.at[x,'\'MLII\'']
    df_222anno.at[index,'Patient'] = '222'
for index,x in enumerate(Sample_223anno):
    df_223anno.at[index,'MLII'] = df_223.at[x,'\'MLII\'']
    df_223anno.at[index,'Patient'] = '223'
for index,x in enumerate(Sample_228anno):
    df_228anno.at[index,'MLII'] = df_228.at[x,'\'MLII\'']
    df_228anno.at[index,'Patient'] = '228'
for index,x in enumerate(Sample_230anno):
    df_230anno.at[index,'MLII'] = df_230.at[x,'\'MLII\'']
    df_230anno.at[index,'Patient'] = '230'
for index,x in enumerate(Sample_231anno):
    df_231anno.at[index,'MLII'] = df_231.at[x,'\'MLII\'']
    df_231anno.at[index,'Patient'] = '231'

# left here
for index,x in enumerate(Sample_116anno):
    df_116anno.at[index,'MLII'] = df_116.at[x,'\'MLII\'']
    df_116anno.at[index,'Patient'] = '116'
for index,x in enumerate(Sample_117anno):
    df_117anno.at[index,'MLII'] = df_117.at[x,'\'MLII\'']
    df_117anno.at[index,'Patient'] = '117'
for index,x in enumerate(Sample_118anno):
    df_118anno.at[index,'MLII'] = df_118.at[x,'\'MLII\'']
    df_118anno.at[index,'Patient'] = '118'
for index,x in enumerate(Sample_119anno):
    df_119anno.at[index,'MLII'] = df_119.at[x,'\'MLII\'']
    df_119anno.at[index,'Patient'] = '119'
for index,x in enumerate(Sample_121anno):
    df_121anno.at[index,'MLII'] = df_121.at[x,'\'MLII\'']
    df_121anno.at[index,'Patient'] = '121'
for index,x in enumerate(Sample_122anno):
    df_122anno.at[index,'MLII'] = df_122.at[x,'\'MLII\'']
    df_122anno.at[index,'Patient'] = '122'
for index,x in enumerate(Sample_123anno):
    df_123anno.at[index,'MLII'] = df_123.at[x,'\'MLII\'']
    df_123anno.at[index,'Patient'] = '123'
for index,x in enumerate(Sample_124anno):
    df_124anno.at[index,'MLII'] = df_124.at[x,'\'MLII\'']
    df_124anno.at[index,'Patient'] = '124'
for index,x in enumerate(Sample_200anno):
    df_200anno.at[index,'MLII'] = df_200.at[x,'\'MLII\'']
    df_200anno.at[index,'Patient'] = '200'
for index,x in enumerate(Sample_201anno):
    df_201anno.at[index,'MLII'] = df_201.at[x,'\'MLII\'']
    df_201anno.at[index,'Patient'] = '201'
for index,x in enumerate(Sample_202anno):
    df_202anno.at[index,'MLII'] = df_202.at[x,'\'MLII\'']
    df_202anno.at[index,'Patient'] = '202'
for index,x in enumerate(Sample_203anno):
    df_203anno.at[index,'MLII'] = df_203.at[x,'\'MLII\'']
    df_203anno.at[index,'Patient'] = '203'
for index,x in enumerate(Sample_205anno):
    df_205anno.at[index,'MLII'] = df_205.at[x,'\'MLII\'']
    df_205anno.at[index,'Patient'] = '205'
for index,x in enumerate(Sample_207anno):
    df_207anno.at[index,'MLII'] = df_207.at[x,'\'MLII\'']
    df_207anno.at[index,'Patient'] = '207'
for index,x in enumerate(Sample_208anno):
    df_208anno.at[index,'MLII'] = df_208.at[x,'\'MLII\'']
    df_208anno.at[index,'Patient'] = '208'
for index,x in enumerate(Sample_100anno):
    df_100anno.at[index,'MLII'] = df_100.at[x,'MLII']
    df_100anno.at[index,'Patient'] = '100'
for index,x in enumerate(Sample_101anno):
    df_101anno.at[index,'MLII'] = df_101.at[x,'\'MLII\'']
    df_101anno.at[index,'Patient'] = '101'
for index,x in enumerate(Sample_103anno):
    df_103anno.at[index,'MLII'] = df_103.at[x,'\'MLII\'']
    df_103anno.at[index,'Patient'] = '103'
for index,x in enumerate(Sample_105anno):
    df_105anno.at[index,'MLII'] = df_105.at[x,'\'MLII\'']
    df_105anno.at[index,'Patient'] = '105'
for index,x in enumerate(Sample_106anno):
    df_106anno.at[index,'MLII'] = df_106.at[x,'\'MLII\'']
    df_106anno.at[index,'Patient'] = '106'
for index,x in enumerate(Sample_107anno):
    df_107anno.at[index,'MLII'] = df_107.at[x,'\'MLII\'']
    df_107anno.at[index,'Patient'] = '107'
for index,x in enumerate(Sample_108anno):
    df_108anno.at[index,'MLII'] = df_108.at[x,'\'MLII\'']
    df_108anno.at[index,'Patient'] = '108'
for index,x in enumerate(Sample_109anno):
    df_109anno.at[index,'MLII'] = df_109.at[x,'\'MLII\'']
    df_109anno.at[index,'Patient'] = '109'
for index,x in enumerate(Sample_111anno):
    df_111anno.at[index,'MLII'] = df_111.at[x,'\'MLII\'']
    df_111anno.at[index,'Patient'] = '111'
for index,x in enumerate(Sample_112anno):
    df_112anno.at[index,'MLII'] = df_112.at[x,'\'MLII\'']
    df_112anno.at[index,'Patient'] = '112'
for index,x in enumerate(Sample_113anno):
    df_113anno.at[index,'MLII'] = df_113.at[x,'\'MLII\'']
    df_113anno.at[index,'Patient'] = '113'
for index,x in enumerate(Sample_114anno):
    df_114anno.at[index,'MLII'] = df_114.at[x,'\'MLII\'']
    df_114anno.at[index,'Patient'] = '114'
for index,x in enumerate(Sample_115anno):
    df_115anno.at[index,'MLII'] = df_115.at[x,'\'MLII\'']
    df_115anno.at[index,'Patient'] = '115'

for index,x in enumerate(Sample_232anno):
    df_232anno.at[index,'MLII'] = df_232.at[x,'\'MLII\'']
    df_232anno.at[index,'Patient'] = '232'
for index,x in enumerate(Sample_233anno):
    df_233anno.at[index,'MLII'] = df_233.at[x,'\'MLII\'']
    df_233anno.at[index,'Patient'] = '233'
for index,x in enumerate(Sample_234anno):
    df_234anno.at[index,'MLII'] = df_234.at[x,'\'MLII\'']
    df_234anno.at[index,'Patient'] = '234'

# %%
df_100anno.rename(columns={'Time ':'Time'},inplace=True)
df_101anno.rename(columns={'Time ':'Time'},inplace=True)
df_103anno.rename(columns={'Time ':'Time'},inplace=True)
df_105anno.rename(columns={'Time ':'Time'},inplace=True)
df_106anno.rename(columns={'Time ':'Time'},inplace=True)
df_107anno.rename(columns={'Time ':'Time'},inplace=True)
df_108anno.rename(columns={'Time ':'Time'},inplace=True)
df_109anno.rename(columns={'Time ':'Time'},inplace=True)
df_111anno.rename(columns={'Time ':'Time'},inplace=True)
df_112anno.rename(columns={'Time ':'Time'},inplace=True)
df_113anno.rename(columns={'Time ':'Time'},inplace=True)
df_114anno.rename(columns={'Time ':'Time'},inplace=True)
df_115anno.rename(columns={'Time ':'Time'},inplace=True)
df_116anno.rename(columns={'Time ':'Time'},inplace=True)
df_117anno.rename(columns={'Time ':'Time'},inplace=True)
df_118anno.rename(columns={'Time ':'Time'},inplace=True)
df_119anno.rename(columns={'Time ':'Time'},inplace=True)
df_121anno.rename(columns={'Time ':'Time'},inplace=True)
df_122anno.rename(columns={'Time ':'Time'},inplace=True)
df_123anno.rename(columns={'Time ':'Time'},inplace=True)
df_124anno.rename(columns={'Time ':'Time'},inplace=True)
df_200anno.rename(columns={'Time ':'Time'},inplace=True)
df_201anno.rename(columns={'Time ':'Time'},inplace=True)
df_202anno.rename(columns={'Time ':'Time'},inplace=True)
df_203anno.rename(columns={'Time ':'Time'},inplace=True)
df_205anno.rename(columns={'Time ':'Time'},inplace=True)
df_207anno.rename(columns={'Time ':'Time'},inplace=True)
df_208anno.rename(columns={'Time ':'Time'},inplace=True)
df_209anno.rename(columns={'Time ':'Time'},inplace=True)
df_210anno.rename(columns={'Time ':'Time'},inplace=True)
df_212anno.rename(columns={'Time ':'Time'},inplace=True)
df_213anno.rename(columns={'Time ':'Time'},inplace=True)
df_214anno.rename(columns={'Time ':'Time'},inplace=True)
df_215anno.rename(columns={'Time ':'Time'},inplace=True)
df_217anno.rename(columns={'Time ':'Time'},inplace=True)
df_219anno.rename(columns={'Time ':'Time'},inplace=True)
df_220anno.rename(columns={'Time ':'Time'},inplace=True)
df_221anno.rename(columns={'Time ':'Time'},inplace=True)
df_222anno.rename(columns={'Time ':'Time'},inplace=True)
df_223anno.rename(columns={'Time ':'Time'},inplace=True)
df_228anno.rename(columns={'Time ':'Time'},inplace=True)
df_230anno.rename(columns={'Time ':'Time'},inplace=True)
df_231anno.rename(columns={'Time ':'Time'},inplace=True)
df_232anno.rename(columns={'Time ':'Time'},inplace=True)
df_233anno.rename(columns={'Time ':'Time'},inplace=True)
df_234anno.rename(columns={'Time ':'Time'},inplace=True)

# %% [markdown]
# # Exclude rhythm annotation

# %%
df_100anno.reset_index(drop=True)
df_101anno.reset_index(drop=True)
df_103anno.reset_index(drop=True)
df_105anno.reset_index(drop=True)
df_106anno.reset_index(drop=True)
df_107anno.reset_index(drop=True)
df_108anno.reset_index(drop=True)
df_109anno.reset_index(drop=True)
df_111anno.reset_index(drop=True)
df_112anno.reset_index(drop=True)
df_113anno.reset_index(drop=True)
df_114anno.reset_index(drop=True)
df_115anno.reset_index(drop=True)
df_116anno.reset_index(drop=True)
df_117anno.reset_index(drop=True)
df_118anno.reset_index(drop=True)
df_119anno.reset_index(drop=True)
df_121anno.reset_index(drop=True)
df_122anno.reset_index(drop=True)
df_123anno.reset_index(drop=True)
df_124anno.reset_index(drop=True)
df_200anno.reset_index(drop=True)
df_201anno.reset_index(drop=True)
df_202anno.reset_index(drop=True)
df_203anno.reset_index(drop=True)
df_205anno.reset_index(drop=True)
df_207anno.reset_index(drop=True)
df_208anno.reset_index(drop=True)
df_209anno.reset_index(drop=True)
df_210anno.reset_index(drop=True)
df_212anno.reset_index(drop=True)
df_213anno.reset_index(drop=True)
df_214anno.reset_index(drop=True)
df_215anno.reset_index(drop=True)
df_217anno.reset_index(drop=True)
df_219anno.reset_index(drop=True)
df_220anno.reset_index(drop=True)
df_221anno.reset_index(drop=True)
df_222anno.reset_index(drop=True)
df_223anno.reset_index(drop=True)
df_228anno.reset_index(drop=True)
df_230anno.reset_index(drop=True)
df_231anno.reset_index(drop=True)
df_232anno.reset_index(drop=True)
df_233anno.reset_index(drop=True)
df_234anno.reset_index(drop=True)
# Out:
#            Time  Sample Type Patient      MLII     1     2     3     4     5  \
# 0      0:00.144      52    +     234  0.465753  NULL  NULL  NULL  NULL  NULL
# 1      0:00.375     135    N     234  0.780822  NULL  NULL  NULL  NULL  NULL
# 2      0:01.017     366    N     234  0.794521  NULL  NULL  NULL  NULL  NULL
# 3      0:01.683     606    N     234  0.796347  NULL  NULL  NULL  NULL  NULL
# 4      0:02.336     841    N     234  0.786301  NULL  NULL  NULL  NULL  NULL
# ...         ...     ...  ...     ...       ...   ...   ...   ...   ...   ...
# 2759  30:02.214  648797    N     234  0.792694  NULL  NULL  NULL  NULL  NULL
# 2760  30:02.889  649040    N     234  0.784475  NULL  NULL  NULL  NULL  NULL
# 2761  30:03.589  649292    N     234  0.758904  NULL  NULL  NULL  NULL  NULL
# 2762  30:04.267  649536    N     234  0.780822  NULL  NULL  NULL  NULL  NULL
# 2763  30:04.922  649772    N     234  0.776256  NULL  NULL  NULL  NULL  NULL
#
# ...

# %% [markdown]
# # Pre-processing
# Feature enhancing by deleting the non-heartbeat annotations

# %%
non_beat_annotations = '[!]x()ptu`\'^|~+sT*D="@'

for index,row in df_100anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_100anno.drop(index,inplace=True)
for index,row in df_101anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_101anno.drop(index,inplace=True)
for index,row in df_103anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_103anno.drop(index,inplace=True)
for index,row in df_105anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_105anno.drop(index,inplace=True)
for index,row in df_106anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_106anno.drop(index,inplace=True)
for index,row in df_107anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_107anno.drop(index,inplace=True)
for index,row in df_108anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_108anno.drop(index,inplace=True)
for index,row in df_109anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_109anno.drop(index,inplace=True)
for index,row in df_111anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_111anno.drop(index,inplace=True)
for index,row in df_112anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_112anno.drop(index,inplace=True)
for index,row in df_113anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_113anno.drop(index,inplace=True)
for index,row in df_114anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_114anno.drop(index,inplace=True)
for index,row in df_115anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_115anno.drop(index,inplace=True)
for index,row in df_116anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_116anno.drop(index,inplace=True)
for index,row in df_117anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_117anno.drop(index,inplace=True)
for index,row in df_118anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_118anno.drop(index,inplace=True)
for index,row in df_119anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_119anno.drop(index,inplace=True)
for index,row in df_121anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_121anno.drop(index,inplace=True)
for index,row in df_122anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_122anno.drop(index,inplace=True)
for index,row in df_123anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_123anno.drop(index,inplace=True)
for index,row in df_124anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_124anno.drop(index,inplace=True)
for index,row in df_200anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_200anno.drop(index,inplace=True)
for index,row in df_201anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_201anno.drop(index,inplace=True)
for index,row in df_202anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_202anno.drop(index,inplace=True)
for index,row in df_203anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_203anno.drop(index,inplace=True)
for index,row in df_205anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_205anno.drop(index,inplace=True)
for index,row in df_207anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_207anno.drop(index,inplace=True)
for index,row in df_208anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_208anno.drop(index,inplace=True)
for index,row in df_209anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_209anno.drop(index,inplace=True)
for index,row in df_210anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_210anno.drop(index,inplace=True)
for index,row in df_212anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_212anno.drop(index,inplace=True)
for index,row in df_213anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_213anno.drop(index,inplace=True)
for index,row in df_214anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_214anno.drop(index,inplace=True)
for index,row in df_215anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_215anno.drop(index,inplace=True)
for index,row in df_217anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_217anno.drop(index,inplace=True)
for index,row in df_219anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_219anno.drop(index,inplace=True)
for index,row in df_220anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_220anno.drop(index,inplace=True)
for index,row in df_221anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_221anno.drop(index,inplace=True)
for index,row in df_222anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_222anno.drop(index,inplace=True)
for index,row in df_223anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_223anno.drop(index,inplace=True)
for index,row in df_228anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_228anno.drop(index,inplace=True)
for index,row in df_230anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_230anno.drop(index,inplace=True)
for index,row in df_231anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_231anno.drop(index,inplace=True)
for index,row in df_232anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_232anno.drop(index,inplace=True)
for index,row in df_233anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_233anno.drop(index,inplace=True)
for index,row in df_234anno.iterrows():
    if non_beat_annotations.find(row['Type']) > -1 or row['Sample'] < 50:
        df_234anno.drop(index,inplace=True)

# %% [markdown]
# # Pre-processing
# Saving the previous 50 values before the QRS complex using the raw datasets.

# %%
for index,row in df_100anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_100anno.at[index,index_2] = df_100['MLII'][row['Sample']-index_2]

# %%
for index,row in df_100anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_100anno.at[index,index_2] = df_100.iloc[:,1][row['Sample']-index_2]
for index,row in df_101anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_101anno.at[index,index_2] = df_101.iloc[:,1][row['Sample']-index_2]
for index,row in df_103anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
          df_103anno.at[index,index_2] = df_103.iloc[:,1][row['Sample']-index_2]
for index,row in df_105anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_105anno.at[index,index_2] = df_105.iloc[:,1][row['Sample']-index_2]
for index,row in df_106anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_106anno.at[index,index_2] = df_106.iloc[:,1][row['Sample']-index_2]
for index,row in df_107anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_107anno.at[index,index_2] = df_107.iloc[:,1][row['Sample']-index_2]
for index,row in df_108anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_108anno.at[index,index_2] = df_108.iloc[:,1][row['Sample']-index_2]
for index,row in df_109anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_109anno.at[index,index_2] = df_109.iloc[:,1][row['Sample']-index_2]
for index,row in df_111anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_111anno.at[index,index_2] = df_111.iloc[:,1][row['Sample']-index_2]
for index,row in df_112anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_112anno.at[index,index_2] = df_112.iloc[:,1][row['Sample']-index_2]
for index,row in df_113anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_113anno.at[index,index_2] = df_113.iloc[:,1][row['Sample']-index_2]
for index,row in df_114anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_114anno.at[index,index_2] = df_114.iloc[:,1][row['Sample']-index_2]
for index,row in df_115anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_115anno.at[index,index_2] = df_115.iloc[:,1][row['Sample']-index_2]
for index,row in df_116anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_116anno.at[index,index_2] = df_116.iloc[:,1][row['Sample']-index_2]
for index,row in df_117anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_117anno.at[index,index_2] = df_117.iloc[:,1][row['Sample']-index_2]
for index,row in df_118anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_118anno.at[index,index_2] = df_118.iloc[:,1][row['Sample']-index_2]
for index,row in df_119anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_119anno.at[index,index_2] = df_119.iloc[:,1][row['Sample']-index_2]
for index,row in df_121anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_121anno.at[index,index_2] = df_121.iloc[:,1][row['Sample']-index_2]
for index,row in df_122anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_122anno.at[index,index_2] = df_122.iloc[:,1][row['Sample']-index_2]
for index,row in df_123anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_123anno.at[index,index_2] = df_123.iloc[:,1][row['Sample']-index_2]
for index,row in df_124anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_124anno.at[index,index_2] = df_124.iloc[:,1][row['Sample']-index_2]
for index,row in df_200anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_200anno.at[index,index_2] = df_200.iloc[:,1][row['Sample']-index_2]
for index,row in df_201anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_201anno.at[index,index_2] = df_201.iloc[:,1][row['Sample']-index_2]
for index,row in df_202anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_202anno.at[index,index_2] = df_202.iloc[:,1][row['Sample']-index_2]
for index,row in df_203anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_203anno.at[index,index_2] = df_203.iloc[:,1][row['Sample']-index_2]
for index,row in df_205anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_205anno.at[index,index_2] = df_205.iloc[:,1][row['Sample']-index_2]
for index,row in df_207anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_207anno.at[index,index_2] = df_207.iloc[:,1][row['Sample']-index_2]
for index,row in df_208anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_208anno.at[index,index_2] = df_208.iloc[:,1][row['Sample']-index_2]
for index,row in df_209anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_209anno.at[index,index_2] = df_209.iloc[:,1][row['Sample']-index_2]
for index,row in df_210anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_210anno.at[index,index_2] = df_210.iloc[:,1][row['Sample']-index_2]
for index,row in df_212anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_212anno.at[index,index_2] = df_212.iloc[:,1][row['Sample']-index_2]
for index,row in df_213anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_213anno.at[index,index_2] = df_213.iloc[:,1][row['Sample']-index_2]
for index,row in df_214anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_214anno.at[index,index_2] = df_214.iloc[:,1][row['Sample']-index_2]
for index,row in df_215anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_215anno.at[index,index_2] = df_215.iloc[:,1][row['Sample']-index_2]
for index,row in df_217anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_217anno.at[index,index_2] = df_217.iloc[:,1][row['Sample']-index_2]
for index,row in df_219anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_219anno.at[index,index_2] = df_219.iloc[:,1][row['Sample']-index_2]
for index,row in df_220anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_220anno.at[index,index_2] = df_220.iloc[:,1][row['Sample']-index_2]
for index,row in df_221anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_221anno.at[index,index_2] = df_221.iloc[:,1][row['Sample']-index_2]
for index,row in df_222anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_222anno.at[index,index_2] = df_222.iloc[:,1][row['Sample']-index_2]
for index,row in df_223anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_223anno.at[index,index_2] = df_223.iloc[:,1][row['Sample']-index_2]
for index,row in df_228anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_228anno.at[index,index_2] = df_228.iloc[:,1][row['Sample']-index_2]
for index,row in df_230anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_230anno.at[index,index_2] = df_230.iloc[:,1][row['Sample']-index_2]
for index,row in df_231anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_231anno.at[index,index_2] = df_231.iloc[:,1][row['Sample']-index_2]
for index,row in df_232anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_232anno.at[index,index_2] = df_232.iloc[:,1][row['Sample']-index_2]
for index,row in df_233anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_233anno.at[index,index_2] = df_233.iloc[:,1][row['Sample']-index_2]
for index,row in df_234anno.iterrows():
    for index_2 in range(1,51):
        if(row['Sample']-index_2 > -1):
            df_234anno.at[index,index_2] = df_234.iloc[:,1][row['Sample']-index_2]

# %%
df_101anno.head()
# Out:
#        Time  Sample Type Patient      MLII         1         2         3  \
# 1  0:00.231      83    N     101  0.757819  0.761394  0.719392  0.662198
# 2  0:01.100     396    N     101  0.749777  0.736372  0.690795  0.636282
# 3  0:01.975     711    N     101  0.775693  0.761394  0.717605  0.663986
# 4  0:02.867    1032    N     101  0.763181  0.741734  0.695264  0.649687
# 5  0:03.800    1368    N     101  0.764075  0.742627  0.696157  0.644325
#
#           4         5  ...        41        42        43        44        45  \
# 1   0.61126  0.565684  ...  0.522788   0.52815  0.529937  0.529937  0.530831
# 2    0.5916  0.552279  ...  0.521895  0.525469  0.529044  0.529937  0.530831
# 3  0.620197  0.579088  ...  0.532618  0.535299  0.533512  0.533512  0.531725
# 4  0.604111  0.563003  ...  0.511171  0.513852  0.519214  0.521895  0.521001
# 5  0.599643  0.559428  ...  0.510277  0.511171  0.512064  0.515639   0.51832
#
#          46        47        48        49        50
# ...

# %%
df_train = df_100anno.append(df_101anno)
df_train = df_train.append(df_103anno)
df_train = df_train.append(df_105anno)
df_train = df_train.append(df_106anno)
df_train = df_train.append(df_107anno)
df_train = df_train.append(df_108anno)
df_train = df_train.append(df_109anno)
df_train = df_train.append(df_111anno)
df_train = df_train.append(df_112anno)
df_train = df_train.append(df_113anno)
df_train = df_train.append(df_114anno)
df_train = df_train.append(df_115anno)
df_train = df_train.append(df_116anno)
df_train = df_train.append(df_118anno)
df_train = df_train.append(df_119anno)
df_train = df_train.append(df_124anno)
df_train = df_train.append(df_200anno)
df_train = df_train.append(df_201anno)
df_train = df_train.append(df_202anno)
df_train = df_train.append(df_203anno)
df_train = df_train.append(df_205anno)
df_train = df_train.append(df_207anno)
df_train = df_train.append(df_208anno)
df_train = df_train.append(df_209anno)
df_train = df_train.append(df_210anno)
df_train = df_train.append(df_213anno)
df_train = df_train.append(df_215anno)
df_train = df_train.append(df_217anno)
df_train = df_train.append(df_219anno)
df_train = df_train.append(df_222anno)
df_train = df_train.append(df_223anno)
df_train = df_train.append(df_228anno)
df_train = df_train.append(df_230anno)
df_train = df_train.append(df_234anno)
# Out:
# C:\Users\Tudi\AppData\Local\Temp\ipykernel_13076\2981457542.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train = df_100anno.append(df_101anno)
# C:\Users\Tudi\AppData\Local\Temp\ipykernel_13076\2981457542.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train = df_train.append(df_103anno)
# C:\Users\Tudi\AppData\Local\Temp\ipykernel_13076\2981457542.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train = df_train.append(df_105anno)
# C:\Users\Tudi\AppData\Local\Temp\ipykernel_13076\2981457542.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train = df_train.append(df_106anno)
# ...

# %%
# 5 healthy patients for test

df_test = df_230anno.append(df_123anno)
df_test = df_test.append(df_122anno)
df_test = df_test.append(df_121anno)
df_test = df_test.append(df_117anno)
# 4 patients with PVC
df_test = df_test.append(df_233anno)
df_test = df_test.append(df_231anno)
df_test = df_test.append(df_228anno)
df_test = df_test.append(df_221anno)
# 1 patient with APB
df_test = df_test.append(df_220anno)
# 1 Patient with LBBB
df_test = df_test.append(df_214anno)
# 1 patient with RBBB
df_test = df_test.append(df_212anno)


df_test = df_test.append(df_232anno)
# Out:
# C:\Users\Tudi\AppData\Local\Temp\ipykernel_13076\338324278.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test = df_230anno.append(df_123anno)
# C:\Users\Tudi\AppData\Local\Temp\ipykernel_13076\338324278.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test = df_test.append(df_122anno)
# C:\Users\Tudi\AppData\Local\Temp\ipykernel_13076\338324278.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test = df_test.append(df_121anno)
# C:\Users\Tudi\AppData\Local\Temp\ipykernel_13076\338324278.py:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test = df_test.append(df_117anno)
# ...

# %%
print(df_train['Type'].value_counts())
# Out:
# N    59952
# L     6072
# V     5635
# R     3783
# /     3620
# A     1060
# F      790
# f      260
# j      228
# a      150
# E      106
# J       83
# e       16
# Q       13
# B        4
# S        2
# Name: Type, dtype: int64

# %% [markdown]
# # DATA IMPUTATION

# %%
df_train['Type'] = df_train['Type'].replace(['A','/','f','+','V','~','|','Q','F','J','j','a','x','L',']','[','R','!','E','S','e'],1)
df_train['Type'] = df_train['Type'].replace(['N'],0)
df_train['Type'] = df_train['Type'].replace(['B'],1) # instead of using symbol  "  it was changed to B 
print(df_train['Type'].value_counts())

print(df_train['Type'].value_counts()[1] / df_train['Type'].value_counts()[0])

df_test['Type'] = df_test['Type'].replace(['A','/','f','+','V','~','|','Q','F','J','j','a','x','L',']','[','R','!','E','S','e'],1)
df_test['Type'] = df_test['Type'].replace(['N'],0)
df_test['Type'] = df_test['Type'].replace(['B'],1) # instead of using symbol  "  it was changed to B 
print(df_test['Type'].value_counts())

print(df_test['Type'].value_counts()[1] / df_test['Type'].value_counts()[0])
# Out:
# 0    59952
# 1    21822
# Name: Type, dtype: int64
# 0.3639911929543635
# 0    20548
# 1     7653
# Name: Type, dtype: int64
# 0.37244500681331516

# %% [markdown]
# # Personwise Data visualization
#
# Plotting patient for 4 heartbeats.

# %%
import matplotlib.pyplot as plt

# %%
from asyncio.windows_events import NULL


patient_100_last_50 = df_train.iloc[1,4:55].values.tolist()
patient_sample_index = df_train.iloc[1,1]

patient_100_raw_200 = df_100.iloc[:,1].values[patient_sample_index - 200:patient_sample_index  + 200].tolist()

size_1 = range(150,150 + len(patient_100_last_50))
size_2 = range(0,len(patient_100_raw_200))

patient_100_last_50 = patient_100_last_50[::-1]

# %%
# Plotting how it would look like we take the interval [t, t - 50] and plot it starting from MLII column

fig, ax = plt.subplots()
ax.plot(size_2, patient_100_raw_200, color='green')
ax.plot(size_1, patient_100_last_50, color = 'red')
legend = ax.legend(loc='center right', fontsize='x-large')
plt.xlabel('Samples')
plt.ylabel('Normalized Amplitude')
plt.title('Column distribution')
plt.savefig('something.png')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
value_counts = df_train['Type'].value_counts()
plt.pie(value_counts, labels=[1,0], colors=['green','red'],autopct='%1.1f%%')
figure = plt.gcf()
figure.gca().add_artist(plt.Circle( (0,0), 0.7, color='white'))
plt.tight_layout()
plt.show()

# %%
df_train.to_csv('data_8_train.csv')
df_test.to_csv('data_8_test.csv')
